# %% [markdown]
# I want to make graphs with the github logo on it.  \uF09B

# %%
import matplotlib.pyplot as plt
import fontawesome as fa

print(f"Hello, {fa.icons['globe']} World!")
# Out:
# Hello,  World!

# %%
# %matplotlib inline

plt.plot([1,2,3],[4,5,6])

ghLogo = u"\uf09b"
liLogo = u"\uf08c"
txt = f"{ghLogo} datawolf04 {liLogo} steven-wolf-253b6625a"
plt.figtext(0.5,0.01, txt,family=['DejaVu Sans','FontAwesome'])

plt.show()
